# %% [markdown]
# ### Titulo

# %% [markdown]
# #### explicacion despues de aplicar los primeros dos pasos del metodo crisp, entender el modelo airbnb, navegr por pagna y ser usuario, se analizo la data disponible y se plantearon las siguientes preguntas

# %% [markdown]
# 1. que influencia tiene la ubicacion en la ocupacion y si su importancia cambia por ciudad
# 2. que influencia tiene el host y el tipo de lugar
# 3. que influencia las reviews
#
# en general encontrar las variables criticas para aumentar la ocupacion de una propiedad agrupadas en ubicación, host, place, y reviews

# %%
import pandas as pd
import numpy as np

# %%
# Open calendar data
boston_calendar = pd.read_csv("boston_airbnb_data/calendar.csv")
seattle_calendar = pd.read_csv("seattle_airbnb_data/calendar.csv")

# %%
# Open listings data
boston_listings = pd.read_csv("boston_airbnb_data/listings.csv")
seattle_listings = pd.read_csv("seattle_airbnb_data/listings.csv")

# %%
# Concatenate the data calendar from Boston and Seattle
df_calendar = pd.concat([boston_calendar,seattle_calendar ], axis=0,ignore_index=True)
# Drop price column because we don't need it for our analysis
df_calendar = df_calendar.drop('price', axis=1)

# %%
# Get one column for each variable on for t(true) and one for f(false)
df_calendar = pd.concat([df_calendar.drop('available', axis=1), pd.get_dummies(df_calendar['available'], prefix='available', prefix_sep='_')], axis=1)

# %%
# Group by each list id by adding the number of times each list_id is available and unavailable
df_occupation = df_calendar.groupby("listing_id").sum()
# Add a column with the occupancy percentage, which is the number of days occupied divided by the total number of days registered
df_occupation["occupation_percentage"] = df_occupation["available_f"]*100/(df_occupation["available_f"]+df_occupation["available_t"])
# Drop columns will no longer be used
df_occupation = df_occupation.drop(["available_f","available_t"], axis=1)

# %%
df_occupation
# Out:
#             occupation_percentage
# listing_id
# 3335                    15.342466
# 3353                    31.780822
# 4291                     0.000000
# 5506                     5.753425
# 5682                    15.342466
# ...                           ...
# 14924831                81.917808
# 14928000                 0.000000
# 14928333                 7.123288
# 14933380                77.808219
# 14933461                58.904110
#
# [7403 rows x 1 columns]

# %%
df_listings
# Out:
#             id                            listing_url       scrape_id  \
# 0     12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1      3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2         6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3      1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4      7651065   https://www.airbnb.com/rooms/7651065  20160906204935
# ...        ...                                    ...             ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 3814   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                           name  \
# 0      2016-09-07                     Sunny Bungalow in the City
# 1      2016-09-07              Charming room in pet friendly apt
# 2      2016-09-07               Mexican Folk Art Haven in Boston
# 3      2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4      2016-09-07                            Come Home to Boston
# ...           ...                                            ...
# 3813   2016-01-04             3BR Mountain View House in Seattle
# 3814   2016-01-04              Portage Bay View!-One Bedroom Apt
# 3815   2016-01-04              Private apartment view of Lake WA
# 3816   2016-01-04              Amazing View with Modern Comfort!
# 3817   2016-01-04                      Large Lakefront Apartment
#
#                                                 summary  \
# 0     Cozy, sunny, family home.  Master bedroom high...
# 1     Charming and quiet room in a second floor 1910...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Come experience the comforts of home away from...
# 4     My comfy, clean and relaxing home is one block...
# ...                                                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...
# 3814  800 square foot 1 bedroom basement apartment w...
# 3815  Very comfortable lower unit. Quiet, charming m...
# 3816  Cozy studio condo in the heart on Madison Park...
# 3817  All hardwood floors, fireplace, 65" TV with Xb...
#
#                                                   space  \
# 0     The house has an open and cozy feel at the sam...
# 1     Small but cozy and quite room with a full size...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Most places you find in Boston are small howev...
# 4     Clean, attractive, private room, one block fro...
# ...                                                 ...
# 3813  Our 3BR/2BA house bright, stylish, and wheelch...
# 3814  This space has a great view of Portage Bay wit...
# 3815                                                NaN
# 3816  Fully furnished unit to accommodate most needs...
# 3817                                                NaN
#
#                                             description experiences_offered  \
# 0     Cozy, sunny, family home.  Master bedroom high...                none
# 1     Charming and quiet room in a second floor 1910...                none
# 2     Come stay with a friendly, middle-aged guy in ...                none
# 3     Come experience the comforts of home away from...                none
# 4     My comfy, clean and relaxing home is one block...                none
# ...                                                 ...                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...                none
# 3814  800 square foot 1 bedroom basement apartment w...                none
# 3815  Very comfortable lower unit. Quiet, charming m...                none
# 3816  Cozy studio condo in the heart on Madison Park...                none
# 3817  All hardwood floors, fireplace, 65" TV with Xb...                none
#
#                                   neighborhood_overview  ...  \
# 0     Roslindale is quiet, convenient and friendly. ...  ...
# 1     The room is in Roslindale, a diverse and prima...  ...
# 2     The LOCATION: Roslindale is a safe and diverse...  ...
# 3     Roslindale is a lovely little neighborhood loc...  ...
# 4     I love the proximity to downtown, the neighbor...  ...
# ...                                                 ...  ...
# 3813  We're located near lots of family fun. Woodlan...  ...
# 3814  The neighborhood is a quiet oasis that is clos...  ...
# 3815                                                NaN  ...
# 3816  Madison Park offers a peaceful slow pace upsca...  ...
# 3817                                                NaN  ...
#
#      review_scores_value requires_license license jurisdiction_names  \
# 0                    NaN                f     NaN                NaN
# 1                    9.0                f     NaN                NaN
# 2                   10.0                f     NaN                NaN
# 3                   10.0                f     NaN                NaN
# 4                   10.0                f     NaN                NaN
# ...                  ...              ...     ...                ...
# 3813                 8.0                f     NaN         WASHINGTON
# 3814                10.0                f     NaN         WASHINGTON
# 3815                 NaN                f     NaN         WASHINGTON
# 3816                 NaN                f     NaN         WASHINGTON
# 3817                 NaN                f     NaN         WASHINGTON
#
#      instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                   f            moderate                              f
# 1                   t            moderate                              f
# 2                   f            moderate                              t
# 3                   f            moderate                              f
# 4                   f            flexible                              f
# ...               ...                 ...                            ...
# 3813                f              strict                              f
# 3814                f            moderate                              f
# 3815                f            moderate                              f
# 3816                f            moderate                              f
# 3817                f            flexible                              f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 0                                   f                              1
# 1                                   f                              1
# 2                                   f                              1
# 3                                   f                              1
# 4                                   f                              1
# ...                               ...                            ...
# 3813                                f                              8
# 3814                                f                              1
# 3815                                f                              1
# 3816                                f                              1
# 3817                                f                              1
#
#      reviews_per_month
# 0                  NaN
# 1                 1.30
# 2                 0.47
# 3                 1.00
# 4                 2.25
# ...                ...
# 3813              0.30
# 3814              2.00
# 3815               NaN
# 3816               NaN
# 3817               NaN
#
# [7403 rows x 92 columns]

# %%
# Before concatenating listings dataframes, we need to remove the columns that have boston and not seattle
boston_listings = boston_listings.drop( ['access', 'interaction', 'house_rules'], axis=1)
# Concatenate the data listings from Boston and Seattle
df_listings = pd.concat([boston_listings, seattle_listings], axis=0)

# %%
# Create a consolidate dataframe with all the airbnb dat
df = pd.merge(df_listings, df_occupation,left_on="id",right_on="listing_id", how="inner")

# %%
df
# Out:
#             id                            listing_url       scrape_id  \
# 0     12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1      3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2         6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3      1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4      7651065   https://www.airbnb.com/rooms/7651065  20160906204935
# ...        ...                                    ...             ...
# 7398   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 7399   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 7400  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 7401   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 7402  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                           name  \
# 0      2016-09-07                     Sunny Bungalow in the City
# 1      2016-09-07              Charming room in pet friendly apt
# 2      2016-09-07               Mexican Folk Art Haven in Boston
# 3      2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4      2016-09-07                            Come Home to Boston
# ...           ...                                            ...
# 7398   2016-01-04             3BR Mountain View House in Seattle
# 7399   2016-01-04              Portage Bay View!-One Bedroom Apt
# 7400   2016-01-04              Private apartment view of Lake WA
# 7401   2016-01-04              Amazing View with Modern Comfort!
# 7402   2016-01-04                      Large Lakefront Apartment
#
#                                                 summary  \
# 0     Cozy, sunny, family home.  Master bedroom high...
# 1     Charming and quiet room in a second floor 1910...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Come experience the comforts of home away from...
# 4     My comfy, clean and relaxing home is one block...
# ...                                                 ...
# 7398  Our 3BR/2BA house boasts incredible views of t...
# 7399  800 square foot 1 bedroom basement apartment w...
# 7400  Very comfortable lower unit. Quiet, charming m...
# 7401  Cozy studio condo in the heart on Madison Park...
# 7402  All hardwood floors, fireplace, 65" TV with Xb...
#
#                                                   space  \
# 0     The house has an open and cozy feel at the sam...
# 1     Small but cozy and quite room with a full size...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Most places you find in Boston are small howev...
# 4     Clean, attractive, private room, one block fro...
# ...                                                 ...
# 7398  Our 3BR/2BA house bright, stylish, and wheelch...
# 7399  This space has a great view of Portage Bay wit...
# 7400                                                NaN
# 7401  Fully furnished unit to accommodate most needs...
# 7402                                                NaN
#
#                                             description experiences_offered  \
# 0     Cozy, sunny, family home.  Master bedroom high...                none
# 1     Charming and quiet room in a second floor 1910...                none
# 2     Come stay with a friendly, middle-aged guy in ...                none
# 3     Come experience the comforts of home away from...                none
# 4     My comfy, clean and relaxing home is one block...                none
# ...                                                 ...                 ...
# 7398  Our 3BR/2BA house boasts incredible views of t...                none
# 7399  800 square foot 1 bedroom basement apartment w...                none
# 7400  Very comfortable lower unit. Quiet, charming m...                none
# 7401  Cozy studio condo in the heart on Madison Park...                none
# 7402  All hardwood floors, fireplace, 65" TV with Xb...                none
#
#                                   neighborhood_overview  ... requires_license  \
# 0     Roslindale is quiet, convenient and friendly. ...  ...                f
# 1     The room is in Roslindale, a diverse and prima...  ...                f
# 2     The LOCATION: Roslindale is a safe and diverse...  ...                f
# 3     Roslindale is a lovely little neighborhood loc...  ...                f
# 4     I love the proximity to downtown, the neighbor...  ...                f
# ...                                                 ...  ...              ...
# 7398  We're located near lots of family fun. Woodlan...  ...                f
# 7399  The neighborhood is a quiet oasis that is clos...  ...                f
# 7400                                                NaN  ...                f
# 7401  Madison Park offers a peaceful slow pace upsca...  ...                f
# 7402                                                NaN  ...                f
#
#      license jurisdiction_names instant_bookable cancellation_policy  \
# 0        NaN                NaN                f            moderate
# 1        NaN                NaN                t            moderate
# 2        NaN                NaN                f            moderate
# 3        NaN                NaN                f            moderate
# 4        NaN                NaN                f            flexible
# ...      ...                ...              ...                 ...
# 7398     NaN         WASHINGTON                f              strict
# 7399     NaN         WASHINGTON                f            moderate
# 7400     NaN         WASHINGTON                f            moderate
# 7401     NaN         WASHINGTON                f            moderate
# 7402     NaN         WASHINGTON                f            flexible
#
#      require_guest_profile_picture  require_guest_phone_verification  \
# 0                                f                                 f
# 1                                f                                 f
# 2                                t                                 f
# 3                                f                                 f
# 4                                f                                 f
# ...                            ...                               ...
# 7398                             f                                 f
# 7399                             f                                 f
# 7400                             f                                 f
# 7401                             f                                 f
# 7402                             f                                 f
#
#      calculated_host_listings_count reviews_per_month occupation_percentage
# 0                                 1               NaN            100.000000
# 1                                 1              1.30              1.643836
# 2                                 1              0.47             12.602740
# 3                                 1              1.00             73.150685
# 4                                 1              2.25              8.493151
# ...                             ...               ...                   ...
# 7398                              8              0.30             91.232877
# 7399                              1              2.00             25.205479
# 7400                              1               NaN             75.890411
# 7401                              1               NaN             50.958904
# 7402                              1               NaN             98.082192
#
# [7403 rows x 93 columns]

# %%
df.isnull().sum()*100/len(df_listings)
# Out:
# id                                   0.000000
# listing_url                          0.000000
# scrape_id                            0.000000
# last_scraped                         0.000000
# name                                 0.000000
#                                       ...
# require_guest_profile_picture        0.000000
# require_guest_phone_verification     0.000000
# calculated_host_listings_count       0.000000
# reviews_per_month                   18.681616
# occupation_percentage                0.000000
# Length: 93, dtype: float64
